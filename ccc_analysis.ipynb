# %%
import numpy as np
import pandas as pd
import scanpy as sc

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# scanpy==1.9.4 anndata==0.9.2 umap==0.5.3 numpy==1.24.4 scipy==1.11.2 pandas==2.1.0 scikit-learn==1.3.0 statsmodels==0.14.0 igraph==0.10.6 louvain==0.8.1 pynndescent==0.5.10
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %% [markdown]
# Reading in and verifying adata

# %%
adata = sc.read_h5ad("/home/timliu/Projects/aging_mice/data/aged_new_celltypes.h5ad")
# Out:
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1838: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.raw = adata

# %%
adata.obs
# Out:
#                            cond  n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCCAAGAAGTCCG-1   aged_naive               2206                 7.699389
# AAACCCAAGATTGCGG-1   aged_naive               2600                 7.863651
# AAACCCAAGCATCAAA-1   aged_naive                495                 6.206576
# AAACCCAAGCTCAGAG-1   aged_naive               3733                 8.225235
# AAACCCACACTGCACG-1   aged_naive               4934                 8.504108
# ...                         ...                ...                      ...
# TTTGTTGGTTCGATTG-1  young_naive               1340                 7.201171
# TTTGTTGTCACACCGG-1  young_naive               4900                 8.497195
# TTTGTTGTCGGTAAGG-1  young_naive               1524                 7.329750
# TTTGTTGTCTGGTGGC-1  young_naive               5574                 8.626048
# TTTGTTGTCTGTCAGA-1  young_naive               1731                 7.457032
#
#                     total_counts  log1p_total_counts  \
# AAACCCAAGAAGTCCG-1        6788.0            8.823059
# AAACCCAAGATTGCGG-1        7295.0            8.895082
# AAACCCAAGCATCAAA-1         888.0            6.790097
# AAACCCAAGCTCAGAG-1       13942.0            9.542733
# AAACCCACACTGCACG-1       25207.0           10.134916
# ...                          ...                 ...
# TTTGTTGGTTCGATTG-1        2654.0            7.884200
# TTTGTTGTCACACCGG-1       18891.0            9.846494
# TTTGTTGTCGGTAAGG-1        2954.0            7.991254
# TTTGTTGTCTGGTGGC-1       25069.0           10.129427
# TTTGTTGTCTGTCAGA-1        4105.0            8.320205
#
#                     pct_counts_in_top_20_genes  total_counts_mt  \
# AAACCCAAGAAGTCCG-1                   21.670595            237.0
# AAACCCAAGATTGCGG-1                   13.927347             98.0
# AAACCCAAGCATCAAA-1                   21.959459              3.0
# AAACCCAAGCTCAGAG-1                   16.468226            204.0
# AAACCCACACTGCACG-1                   23.719602           1545.0
# ...                                        ...              ...
# TTTGTTGGTTCGATTG-1                   17.709118             34.0
# TTTGTTGTCACACCGG-1                   13.800222            665.0
# TTTGTTGTCGGTAAGG-1                   13.981043            122.0
# TTTGTTGTCTGGTGGC-1                   13.889665           1353.0
# TTTGTTGTCTGTCAGA-1                   16.516443            121.0
#
#                     log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCCAAGAAGTCCG-1               5.472270       3.491456                0.0
# AAACCCAAGATTGCGG-1               4.595120       1.343386                0.0
# AAACCCAAGCATCAAA-1               1.386294       0.337838                0.0
# AAACCCAAGCTCAGAG-1               5.323010       1.463205                0.0
# AAACCCACACTGCACG-1               7.343426       6.129250                0.0
# ...                                   ...            ...                ...
# TTTGTTGGTTCGATTG-1               3.555348       1.281085                0.0
# TTTGTTGTCACACCGG-1               6.501290       3.520195                0.0
# TTTGTTGTCGGTAAGG-1               4.812184       4.129993                0.0
# TTTGTTGTCTGGTGGC-1               7.210818       5.397104                0.0
# TTTGTTGTCTGTCAGA-1               4.804021       2.947625                0.0
#
#                     ...  leiden_res0.1  leiden_res0.15  leiden_res0.2  \
# AAACCCAAGAAGTCCG-1  ...              0               0              0
# AAACCCAAGATTGCGG-1  ...              0               0              0
# AAACCCAAGCATCAAA-1  ...              0               6              3
# AAACCCAAGCTCAGAG-1  ...              0               0              0
# AAACCCACACTGCACG-1  ...              1               1              1
# ...                 ...            ...             ...            ...
# TTTGTTGGTTCGATTG-1  ...              0               3              4
# TTTGTTGTCACACCGG-1  ...              1               1              1
# TTTGTTGTCGGTAAGG-1  ...              3               3              4
# TTTGTTGTCTGGTGGC-1  ...              1               1              1
# TTTGTTGTCTGTCAGA-1  ...              0               0              0
#
#                     leiden_res0.25  leiden_res0.375  leiden_res0.5  \
# AAACCCAAGAAGTCCG-1               0                1              0
# AAACCCAAGATTGCGG-1               0                1              0
# AAACCCAAGCATCAAA-1               3                5              4
# AAACCCAAGCTCAGAG-1               0                1              0
# AAACCCACACTGCACG-1               1                0              3
# ...                            ...              ...            ...
# TTTGTTGGTTCGATTG-1               4                4              8
# TTTGTTGTCACACCGG-1               1                0              2
# TTTGTTGTCGGTAAGG-1               4                4              7
# TTTGTTGTCTGGTGGC-1               1                0              3
# TTTGTTGTCTGTCAGA-1               0                2              1
#
#                     leiden_res0.75  leiden_res1.0                  ct  \
# AAACCCAAGAAGTCCG-1               0              5       M2 macrophage
# AAACCCAAGATTGCGG-1               0              2       M2 macrophage
# AAACCCAAGCATCAAA-1              16             17       M2 macrophage
# AAACCCAAGCTCAGAG-1               0              5       M2 macrophage
# AAACCCACACTGCACG-1               3              1  Myoepithelial cell
# ...                            ...            ...                 ...
# TTTGTTGGTTCGATTG-1               9             12       M2 macrophage
# TTTGTTGTCACACCGG-1               2              0  Myoepithelial cell
# TTTGTTGTCGGTAAGG-1               5              7      Dendritic cell
# TTTGTTGTCTGGTGGC-1               3              1  Myoepithelial cell
# TTTGTTGTCTGTCAGA-1               1              3       M2 macrophage
#
#                        cell_type
# AAACCCAAGAAGTCCG-1   Macrophages
# AAACCCAAGATTGCGG-1   Macrophages
# AAACCCAAGCATCAAA-1   Macrophages
# AAACCCAAGCTCAGAG-1   Macrophages
# AAACCCACACTGCACG-1  Cancer cells
# ...                          ...
# TTTGTTGGTTCGATTG-1            DC
# TTTGTTGTCACACCGG-1  Cancer cells
# TTTGTTGTCGGTAAGG-1            DC
# TTTGTTGTCTGGTGGC-1  Cancer cells
# TTTGTTGTCTGTCAGA-1     Monocytes
#
# [32550 rows x 29 columns]

# %%
sc.pl.umap(adata, color = ["cell_type","ct"])
# Out:
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Identifying interactions of interest and prepping adata for LIANA

# %%
adata.obs["cell_type"].unique().tolist()
# Out:
# ['Macrophages',
#  'Cancer cells',
#  'Monocytes',
#  'Cd4_T_cell',
#  'DC',
#  'Neutrophil',
#  'NK',
#  'Delta_Gamma_T_cell',
#  'Activated dendritic cells',
#  'B-cell',
#  'Cd8_T_cell',
#  'Endothelial',
#  'Fibroblasts']

# %%
#Interactions of interest
cells_of_interest = ['Cancer cells', 'Macrophages']

# %%
# Parse through each cell to see if it contains cell types of interest
def categorize_cell(cell_type):
    if cell_type not in cells_of_interest:
        return 'Neither'
    else:
        return cell_type

# %%
# Apply the function to create a new obs
adata.obs['cell_category'] = adata.obs['cell_type'].apply(categorize_cell)

# %%
adata.obs
# Out:
#                            cond  n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCCAAGAAGTCCG-1   aged_naive               2206                 7.699389
# AAACCCAAGATTGCGG-1   aged_naive               2600                 7.863651
# AAACCCAAGCATCAAA-1   aged_naive                495                 6.206576
# AAACCCAAGCTCAGAG-1   aged_naive               3733                 8.225235
# AAACCCACACTGCACG-1   aged_naive               4934                 8.504108
# ...                         ...                ...                      ...
# TTTGTTGGTTCGATTG-1  young_naive               1340                 7.201171
# TTTGTTGTCACACCGG-1  young_naive               4900                 8.497195
# TTTGTTGTCGGTAAGG-1  young_naive               1524                 7.329750
# TTTGTTGTCTGGTGGC-1  young_naive               5574                 8.626048
# TTTGTTGTCTGTCAGA-1  young_naive               1731                 7.457032
#
#                     total_counts  log1p_total_counts  \
# AAACCCAAGAAGTCCG-1        6788.0            8.823059
# AAACCCAAGATTGCGG-1        7295.0            8.895082
# AAACCCAAGCATCAAA-1         888.0            6.790097
# AAACCCAAGCTCAGAG-1       13942.0            9.542733
# AAACCCACACTGCACG-1       25207.0           10.134916
# ...                          ...                 ...
# TTTGTTGGTTCGATTG-1        2654.0            7.884200
# TTTGTTGTCACACCGG-1       18891.0            9.846494
# TTTGTTGTCGGTAAGG-1        2954.0            7.991254
# TTTGTTGTCTGGTGGC-1       25069.0           10.129427
# TTTGTTGTCTGTCAGA-1        4105.0            8.320205
#
#                     pct_counts_in_top_20_genes  total_counts_mt  \
# AAACCCAAGAAGTCCG-1                   21.670595            237.0
# AAACCCAAGATTGCGG-1                   13.927347             98.0
# AAACCCAAGCATCAAA-1                   21.959459              3.0
# AAACCCAAGCTCAGAG-1                   16.468226            204.0
# AAACCCACACTGCACG-1                   23.719602           1545.0
# ...                                        ...              ...
# TTTGTTGGTTCGATTG-1                   17.709118             34.0
# TTTGTTGTCACACCGG-1                   13.800222            665.0
# TTTGTTGTCGGTAAGG-1                   13.981043            122.0
# TTTGTTGTCTGGTGGC-1                   13.889665           1353.0
# TTTGTTGTCTGTCAGA-1                   16.516443            121.0
#
#                     log1p_total_counts_mt  pct_counts_mt  total_counts_ribo  \
# AAACCCAAGAAGTCCG-1               5.472270       3.491456                0.0
# AAACCCAAGATTGCGG-1               4.595120       1.343386                0.0
# AAACCCAAGCATCAAA-1               1.386294       0.337838                0.0
# AAACCCAAGCTCAGAG-1               5.323010       1.463205                0.0
# AAACCCACACTGCACG-1               7.343426       6.129250                0.0
# ...                                   ...            ...                ...
# TTTGTTGGTTCGATTG-1               3.555348       1.281085                0.0
# TTTGTTGTCACACCGG-1               6.501290       3.520195                0.0
# TTTGTTGTCGGTAAGG-1               4.812184       4.129993                0.0
# TTTGTTGTCTGGTGGC-1               7.210818       5.397104                0.0
# TTTGTTGTCTGTCAGA-1               4.804021       2.947625                0.0
#
#                     ...  leiden_res0.15  leiden_res0.2  leiden_res0.25  \
# AAACCCAAGAAGTCCG-1  ...               0              0               0
# AAACCCAAGATTGCGG-1  ...               0              0               0
# AAACCCAAGCATCAAA-1  ...               6              3               3
# AAACCCAAGCTCAGAG-1  ...               0              0               0
# AAACCCACACTGCACG-1  ...               1              1               1
# ...                 ...             ...            ...             ...
# TTTGTTGGTTCGATTG-1  ...               3              4               4
# TTTGTTGTCACACCGG-1  ...               1              1               1
# TTTGTTGTCGGTAAGG-1  ...               3              4               4
# TTTGTTGTCTGGTGGC-1  ...               1              1               1
# TTTGTTGTCTGTCAGA-1  ...               0              0               0
#
#                     leiden_res0.375  leiden_res0.5  leiden_res0.75  \
# AAACCCAAGAAGTCCG-1                1              0               0
# AAACCCAAGATTGCGG-1                1              0               0
# AAACCCAAGCATCAAA-1                5              4              16
# AAACCCAAGCTCAGAG-1                1              0               0
# AAACCCACACTGCACG-1                0              3               3
# ...                             ...            ...             ...
# TTTGTTGGTTCGATTG-1                4              8               9
# TTTGTTGTCACACCGG-1                0              2               2
# TTTGTTGTCGGTAAGG-1                4              7               5
# TTTGTTGTCTGGTGGC-1                0              3               3
# TTTGTTGTCTGTCAGA-1                2              1               1
#
#                     leiden_res1.0                  ct     cell_type  \
# AAACCCAAGAAGTCCG-1              5       M2 macrophage   Macrophages
# AAACCCAAGATTGCGG-1              2       M2 macrophage   Macrophages
# AAACCCAAGCATCAAA-1             17       M2 macrophage   Macrophages
# AAACCCAAGCTCAGAG-1              5       M2 macrophage   Macrophages
# AAACCCACACTGCACG-1              1  Myoepithelial cell  Cancer cells
# ...                           ...                 ...           ...
# TTTGTTGGTTCGATTG-1             12       M2 macrophage            DC
# TTTGTTGTCACACCGG-1              0  Myoepithelial cell  Cancer cells
# TTTGTTGTCGGTAAGG-1              7      Dendritic cell            DC
# TTTGTTGTCTGGTGGC-1              1  Myoepithelial cell  Cancer cells
# TTTGTTGTCTGTCAGA-1              3       M2 macrophage     Monocytes
#
#                    cell_category
# AAACCCAAGAAGTCCG-1   Macrophages
# AAACCCAAGATTGCGG-1   Macrophages
# AAACCCAAGCATCAAA-1   Macrophages
# AAACCCAAGCTCAGAG-1   Macrophages
# AAACCCACACTGCACG-1  Cancer cells
# ...                          ...
# TTTGTTGGTTCGATTG-1       Neither
# TTTGTTGTCACACCGG-1  Cancer cells
# TTTGTTGTCGGTAAGG-1       Neither
# TTTGTTGTCTGGTGGC-1  Cancer cells
# TTTGTTGTCTGTCAGA-1       Neither
#
# [32550 rows x 30 columns]

# %%
sc.pl.umap(adata, color = ["ct","cell_category"])
# Out:
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1207: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(values):
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:1216: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
#Split adata into young and aged
young_adata = adata[adata.obs["cond"] == "young_naive"]
aged_adata = adata[adata.obs["cond"] == "aged_naive"]
# Out:
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
young_adata
# Out:
# View of AnnData object with n_obs × n_vars = 19169 × 32285
#     obs: 'cond', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'outlier', 'doublet_score', 'predicted_doublets', 'leiden_res0.05', 'leiden_res0.1', 'leiden_res0.15', 'leiden_res0.2', 'leiden_res0.25', 'leiden_res0.375', 'leiden_res0.5', 'leiden_res0.75', 'leiden_res1.0', 'ct', 'cell_type', 'cell_category'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'cell_type_colors', 'cond_colors', 'ct_colors', 'hvg', 'leiden', 'leiden_res0.05_colors', 'leiden_res0.15_colors', 'leiden_res0.1_colors', 'leiden_res0.25_colors', 'leiden_res0.2_colors', 'leiden_res0.375_colors', 'leiden_res0.5_colors', 'leiden_res0.75_colors', 'leiden_res1.0_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap', 'cell_category_colors'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap', 'ora_estimate', 'ora_pvals'
#     varm: 'PCs'
#     layers: 'counts', 'log1p_norm'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# Implementing LIANA - Rank Aggregate Used

# %%
import liana as li
from liana.mt import rank_aggregate

# %%
# ?rank_aggregate.__call__
# Out:
# Signature:
# rank_aggregate.__call__(
#     adata: 'an.AnnData | MuData',
#     groupby: 'str',
#     resource_name: 'str' = 'consensus',
#     expr_prop: 'float' = 0.1,
#     min_cells: 'int' = 5,
#     base: 'float' = 2.718281828459045,
#     aggregate_method: 'str' = 'rra',
#     consensus_opts: 'Optional[list]' = None,
#     return_all_lrs: 'bool' = False,
#     key_added: 'str' = 'liana_res',
#     use_raw: 'Optional[bool]' = True,
#     layer: 'Optional[str]' = None,
#     de_method: 'str' = 't-test',
#     n_perms: 'int' = 1000,
#     seed: 'int' = 1337,
#     resource: 'Optional[DataFrame]' = None,
#     interactions: 'Optional[list]' = None,
#     mdata_kwargs: 'dict' = {},
#     inplace: 'bool' = True,
#     verbose: 'Optional[bool]' = False,
# )
# Docstring:
# Get an aggregate of ligand-receptor scores from multiple methods.
#
# Parameters
# ----------
# adata
#     Annotated data object.
# groupby
#     Key to be used for grouping.
# resource_name
#     Name of the resource to be used for ligand-receptor inference. See `li.rs.show_resources()` for available resources.
# expr_prop
#     Minimum expression proportion for the ligands and receptors (+ their subunits) in the
#     corresponding cell identities. Set to 0 to return unfiltered results.
# min_cells
#     Minimum cells (per cell identity if grouped by `groupby`) to be considered for downstream analysis.
# base
#     Exponent base used to reverse the log-transformation of the matrix. Relevant only for the `logfc` method.
# aggregate_method
#     Method aggregation approach, one of ['mean', 'rra'], where `mean` represents the
#     mean rank, while 'rra' is the RobustRankAggregate (Kolde et al., 2014)
#     of the interactions
# consensus_opts
#     Strategies to aggregate interactions across methods.
#     Default is None - i.e. ['Specificity', 'Magnitude'] and both specificity and magnitude are aggregated.
# return_all_lrs
#     Bool whether to return all ligand-receptor pairs, or only those that surpass the `expr_prop`
#     threshold. Ligand-receptor pairs that do not pass the `expr_prop` threshold will be assigned
#     to the *worst* score of the ones that do. `False` by default.
# key_added
#     Key under which the results will be stored in `adata.uns` if `inplace` is True.
# use_raw
#     Use raw attribute of adata if present.
# layer
#     Layer in anndata.AnnData.layers to use. If None, use anndata.AnnData.X.
# de_method
#     Differential expression method. `scanpy.tl.rank_genes_groups` is used to rank genes
#     according to 1vsRest. The default method is 't-test'.
# verbose
#     Verbosity flag.
# n_perms
#     Number of permutations for the permutation test. Relevant only for permutation-based methods
#     (e.g., `CellPhoneDB`). If `None` is passed, no permutation testing is performed.
# seed
#     Random seed for reproducibility.
# resource
#     A pandas dataframe with [`ligand`, `receptor`] columns.
#     If provided will overrule the resource requested via `resource_name`
# interactions
#     List of tuples with ligand-receptor pairs `[(ligand, receptor), ...]` to be used for the analysis.
#     If passed, it will overrule the resource requested via `resource` and `resource_name`.
# mdata_kwargs
#     Keyword arguments to be passed to `li.fun.mdata_to_anndata` if `adata` is an instance of `MuData`.
#     If an AnnData object is passed, these arguments are ignored.
# inplace
#     Whether to store results in place, or else to return them.
#
# Returns
# -------
# If ``inplace = False``, returns a `DataFrame` with ligand-receptor results
# Otherwise, modifies the ``adata`` object with the following key:
#     - :attr:`anndata.AnnData.uns` ``['liana_res']`` with the aforementioned DataFrame
# File:      ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/sc/_rank_aggregate.py
# Type:      method

# %% [markdown]
# Results on Young

# %%
young_adata.raw.X
# Out:
# <19169x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 49176683 stored elements in Compressed Sparse Row format>

# %%
#Run rank aggregate
li.mt.rank_aggregate(young_adata, groupby='cell_category', expr_prop=0.1, verbose=True, resource_name = 'mouseconsensus')
# Out:
# Using `.raw`!
# 6583 features of mat are empty, they will be removed.
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/pandas/core/indexing.py:1819: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/_pipe_utils/_pre.py:142: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# Using resource `mouseconsensus`.
# 0.07 of entities in the resource are missing from the data.
# Generating ligand-receptor stats for 19169 samples and 25702 features
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Assuming that counts were `natural` log-normalized!
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /home/timliu/miniconda3/envs/liana/lib/python3.9/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# Running CellPhoneDB
# 100%|███████████████████████████████████████| 1000/1000 [00:20<00:00, 49.83it/s]
# Running Connectome
# Running log2FC
# Running NATMI
# Running SingleCellSignalR
# Running CellChat
#   3%|█▎                                       | 33/1000 [01:09<34:02,  2.11s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 #Run rank aggregate
# ----> 2 li.mt.rank_aggregate(young_adata, groupby='cell_category', expr_prop=0.1, verbose=True, resource_name = 'mouseconsensus')
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/sc/_rank_aggregate.py:122, in AggregateClass.__call__(self, adata, groupby, resource_name, expr_prop, min_cells, base, aggregate_method, consensus_opts, return_all_lrs, key_added, use_raw, layer, de_method, n_perms, seed, resource, interactions, mdata_kwargs, inplace, verbose)
#     119 else:
#     120     ad = adata
# --> 122 liana_res = liana_pipe(adata=ad,
#     123                        groupby=groupby,
#     124                        resource_name=resource_name,
#     125                        resource=resource,
#     126                        interactions=interactions,
#     127                        expr_prop=expr_prop,
#     128                        min_cells=min_cells,
#     129                        base=base,
#     130                        return_all_lrs=return_all_lrs,
#     131                        de_method=de_method,
#     132                        verbose=verbose,
#     133                        _score=self,
#     134                        use_raw=use_raw,
#     135                        layer=layer,
#     136                        n_perms=n_perms,
#     137                        seed=seed,
#     138                        _methods=self.methods,
#     139                        _aggregate_method=aggregate_method,
#     140                        _consensus_opts=consensus_opts
#     141                        )
#     143 if inplace:
#     144     adata.uns[key_added] = liana_res
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/sc/_liana_pipe.py:190, in liana_pipe(adata, groupby, resource_name, resource, interactions, expr_prop, min_cells, base, de_method, n_perms, seed, verbose, use_raw, layer, supp_columns, return_all_lrs, _score, _methods, _consensus_opts, _aggregate_method)
#     186     if verbose:
#     187         print(f"Running {method.method_name}")
#     189     lrs[method.method_name] = \
# --> 190         _run_method(lr_res=lr_res.copy(),
#     191                     adata=adata,
#     192                     expr_prop=expr_prop,
#     193                     _score=method,
#     194                     _key_cols=_key_cols,
#     195                     _complex_cols=method.complex_cols,
#     196                     _add_cols=method.add_cols,
#     197                     n_perms=n_perms,
#     198                     seed=seed,
#     199                     return_all_lrs=return_all_lrs,
#     200                     verbose=verbose,
#     201                     _aggregate_flag=True
#     202                     )
#     203 if _consensus_opts is not False:
#     204     lr_res = _aggregate(lrs,
#     205                         consensus=_score,
#     206                         aggregate_method=_aggregate_method,
#     207                         _key_cols=_key_cols,
#     208                         _consensus_opts=_consensus_opts,
#     209                         )
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/sc/_liana_pipe.py:387, in _run_method(lr_res, adata, expr_prop, _score, _key_cols, _complex_cols, _add_cols, n_perms, seed, return_all_lrs, verbose, _aggregate_flag)
#     384 if _score.permute:
#     385     # get permutations
#     386     if n_perms is not None:
# --> 387         perms = _get_means_perms(adata=adata,
#     388                                  n_perms=n_perms,
#     389                                  seed=seed,
#     390                                  agg_fun=agg_fun,
#     391                                  norm_factor=norm_factor,
#     392                                  verbose=verbose)
#     393         # get tensor indexes for ligand, receptor, source, target
#     394         ligand_idx, receptor_idx, source_idx, target_idx = _get_mat_idx(adata, lr_res)
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/_pipe_utils/_get_mean_perms.py:53, in _get_means_perms(adata, n_perms, seed, agg_fun, norm_factor, verbose)
#      50     labels_mask[:, ct_idx] = adata.obs['@label'] == label
#      52 # Perm should be a cube /w dims: n_perms x idents x n_genes
# ---> 53 perms = _generate_perms_cube(adata.X, n_perms, labels_mask, seed, agg_fun, verbose)
#      55 return perms
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/liana/method/_pipe_utils/_get_mean_perms.py:72, in _generate_perms_cube(X, n_perms, labels_mask, seed, agg_fun, verbose)
#      70 for perm in tqdm(range(n_perms), disable=not verbose):
#      71     perm_idx = rng.permutation(idx)
# ---> 72     perm_mat = X[perm_idx]
#      73     # populate matrix /w permuted means
#      74     for ct_idx in range(labels_mask.shape[1]):
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/scipy/sparse/_index.py:75, in IndexMixin.__getitem__(self, key)
#      73         return self._get_arrayXint(row, col)
#      74     elif isinstance(col, slice):
# ---> 75         return self._get_arrayXslice(row, col)
#      76 else:  # row.ndim == 2
#      77     if isinstance(col, INT_TYPES):
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/scipy/sparse/_csr.py:335, in _csr_base._get_arrayXslice(self, row, col)
#     333     col = np.arange(*col.indices(self.shape[1]))
#     334     return self._get_arrayXarray(row, col)
# --> 335 return self._major_index_fancy(row)._get_submatrix(minor=col)
#
# File ~/miniconda3/envs/liana/lib/python3.9/site-packages/scipy/sparse/_compressed.py:707, in _cs_matrix._major_index_fancy(self, idx)
#     705 res_indices = np.empty(nnz, dtype=idx_dtype)
#     706 res_data = np.empty(nnz, dtype=self.dtype)
# --> 707 csr_row_index(M, indices, self.indptr, self.indices, self.data,
#     708               res_indices, res_data)
#     710 return self.__class__((res_data, res_indices, res_indptr),
#     711                       shape=new_shape, copy=False)
#
# KeyboardInterrupt:

# %%
# Dotplot

young_dp = li.pl.dotplot(adata = young_adata,
              colour='magnitude_rank',
              size='specificity_rank',
              inverse_size=True,
              inverse_colour=True,
              source_labels= cells_of_interest,
              target_labels= cells_of_interest,
              top_n=20,
              orderby='magnitude_rank',
              orderby_ascending=True,
              figure_size=(8, 7)
             )
young_dp

# %%
young_dp.save("/home/timliu/Projects/aging_mice/plots/young_LIANA_results")

# %%
young_adata.uns['liana_res'].head()

# %%
# Save results
sc.write('/home/timliu/Projects/aging_mice/data/young_subset', young_adata)

# %% [markdown]
# Results on Aged

# %%
aged_adata.raw.X

# %%
li.mt.rank_aggregate(aged_adata, groupby='cell_category', expr_prop=0.1, verbose=True, resource_name = 'mouseconsensus')

# %%
# Old
aged_dp = li.pl.dotplot(adata = aged_adata,
              colour='magnitude_rank',
              size='specificity_rank',
              inverse_size=True,
              inverse_colour=True,
              source_labels= cells_of_interest,
              target_labels= cells_of_interest,
              top_n=20,
              orderby='magnitude_rank',
              orderby_ascending=True,
              figure_size=(8, 7)
             )
aged_dp

# %%
aged_dp.save("/home/timliu/Projects/aging_mice/plots/aged_LIANA_results")

# %%
aged_adata.uns['liana_res'].head()

# %%
sc.write('/home/timliu/Projects/aging_mice/data/aged_subset', aged_adata)
